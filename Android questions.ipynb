# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
android = pd.read_csv("android-games.csv")

# %%
android
# Out:
#       rank                                         title  total ratings  \
# 0        1                  Garena Free Fire - The Cobra       80678661
# 1        2                   PUBG MOBILE: Graffiti Prank       35971961
# 2        3                     Mobile Legends: Bang Bang       25836869
# 3        4                                   Brawl Stars       17181659
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14237554
# ...    ...                                           ...            ...
# 1725    96                     Piknik Słowo - Word Snack         122845
# 1726    97           Wordox – Free multiplayer word game         120476
# 1727    98                             4 Fotos 1 Palavra         114852
# 1728    99                 زوايا - لعبة ستحرك زوايا عقلك         110293
# 1729   100         Word Life - Connect crosswords puzzle         109809
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
android['total ratings'].max()
# Out:
# 80678661

# %% [markdown]
# # percent of 1 star and 5 star

# %%
61935712/80678658
# Out:
# 0.767683964202776

# %%
9654037/80678658
# Out:
# 0.11966035676994033

# %% [markdown]
# # highest average rating game category

# %%
game_action = android[android["category"]=="GAME ACTION"].copy()
game_word = android[android["category"]=="GAME WORD"].copy()
game_card = android[android["category"]=="GAME CARD"].copy()
game_causual = android[android["category"]=="GAME CAUSUAL"].copy()
game_strategy = android[android["category"]=="GAME STRATEGY"].copy()
game_adventure = android[android["category"]=="GAME ADVENTURE"].copy()
game_edu = android[android["category"]=="GAME EDUCATIONAL"].copy()
game_sports = android[android["category"]=="GAME SPORTS"].copy()
game_board = android[android["category"]=="GAME BOARD"].copy()
game_sim = android[android["category"]=="GAME SIMULATION"].copy()
game_trivia= android[android["category"]=="GAME TRIVIA"].copy()
game_puzzle = android[android["category"]=="GAME PUZZLE"].copy()
game_music = android[android["category"]=="GAME MUSIC"].copy()
game_arcade = android[android["category"]=="GAME ARCADE"].copy()
game_casino = android[android["category"]=="GAME CASINO"].copy()
game_role = android[android["category"]=="GAME ROLE PLAYING"].copy()
game_racing = android[android["category"]=="GAME RACING"].copy()

# %%
game_action_mean = game_action["average rating"].mean()
game_word_mean = game_word["average rating"].mean()
game_card_mean = game_card["average rating"].mean()
game_causual_mean = game_causual["average rating"].mean()
game_strategy_mean = game_strategy["average rating"].mean()
game_adventure_mean = game_adventure["average rating"].mean()
game_edu_mean = game_edu["average rating"].mean()
game_sports_mean = game_sports["average rating"].mean()
game_board_mean = game_board["average rating"].mean()
game_sim_mean = game_sim["average rating"].mean()
game_trivia_mean = game_trivia["average rating"].mean()
game_puzzle_mean = game_puzzle["average rating"].mean()
game_music_mean = game_music["average rating"].mean()
game_arcade_mean = game_arcade["average rating"].mean()
game_casino_mean = game_casino["average rating"].mean()
game_role_mean = game_role["average rating"].mean()
game_racing_mean = game_racing["average rating"].mean()

# %%
game_racing_mean
# Out:
# 4.3119999999999985

# %%
game_role_mean
# Out:
# 4.276

# %%
game_casino_mean
# Out:
# 4.437800000000001

# %%
game_arcade_mean
# Out:
# 4.2948999999999975

# %%
game_music_mean
# Out:
# 4.180300000000002

# %%
game_puzzle_mean
# Out:
# 4.3942000000000005

# %%
game_trivia_mean
# Out:
# 4.245699999999999

# %%
game_sim_mean
# Out:
# 4.318199999999999

# %%
game_board_mean
# Out:
# 4.347099999999999

# %%
game_sports_mean
# Out:
# 4.261100000000001

# %%
game_edu_mean
# Out:
# 4.2536000000000005

# %%
game_adventure_mean
# Out:
# 4.2642

# %%
game_action_mean
# Out:
# 4.246100000000001

# %%
game_word_mean
# Out:
# 4.4435849056603764

# %%
game_card_mean
# Out:
# 4.421065573770492

# %%
game_causual_mean
# Out:
# nan

# %%
game_strategy_mean
# Out:
# 4.265

# %%
android["average rating"].mean()
# Out:
# 4.313410404624285

# %%
android["category"].value_counts()
# Out:
# GAME CARD            122
# GAME WORD            106
# GAME CASUAL          102
# GAME RACING          100
# GAME TRIVIA          100
# GAME STRATEGY        100
# GAME SPORTS          100
# GAME SIMULATION      100
# GAME ROLE PLAYING    100
# GAME ACTION          100
# GAME PUZZLE          100
# GAME ADVENTURE       100
# GAME EDUCATIONAL     100
# GAME CASINO          100
# GAME BOARD           100
# GAME ARCADE          100
# GAME MUSIC           100
# Name: category, dtype: int64

# %% [markdown]
# Game Word

# %% [markdown]
# # Highest 5 star ratings

# %%
android["category"].value_counts()
# Out:
# GAME CARD            122
# GAME WORD            106
# GAME CASUAL          102
# GAME RACING          100
# GAME TRIVIA          100
# GAME STRATEGY        100
# GAME SPORTS          100
# GAME SIMULATION      100
# GAME ROLE PLAYING    100
# GAME ACTION          100
# GAME PUZZLE          100
# GAME ADVENTURE       100
# GAME EDUCATIONAL     100
# GAME CASINO          100
# GAME BOARD           100
# GAME ARCADE          100
# GAME MUSIC           100
# Name: category, dtype: int64

# %%
game_action_5star = game_action["5 star ratings"].sum()
game_word_5star = game_word["5 star ratings"].sum()
game_card_5star = game_card["5 star ratings"].sum()
game_causual_5star = game_causual["5 star ratings"].sum()
game_strategy_5star = game_strategy["5 star ratings"].sum()
game_adventure_5star = game_adventure["5 star ratings"].sum()
game_edu_5star = game_edu["5 star ratings"].sum()
game_sports_5star = game_sports["5 star ratings"].sum()
game_board_5star = game_board["5 star ratings"].sum()
game_sim_5star = game_sim["5 star ratings"].sum()
game_trivia_5star = game_trivia["5 star ratings"].sum()
game_puzzle_5star = game_puzzle["5 star ratings"].sum()
game_music_5star = game_music["5 star ratings"].sum()
game_arcade_5star = game_arcade["5 star ratings"].sum()
game_casino_5star = game_casino["5 star ratings"].sum()
game_role_5star = game_role["5 star ratings"].sum()
game_racing_5star = game_racing["5 star ratings"].sum()

# %%
game_action_5star
game_word_5star
game_card_5star
game_causual_5star
game_strategy_5star
game_adventure_5star
game_edu_5star
game_sports_5star
game_board_5star
game_sim_5star
game_trivia_5star
game_puzzle_5star
game_music_5star
game_arcade_5star
game_casino_5star
game_role_5star
game_racing_5star
# Out:
# 98066339

# %%
data={'Name':["GAME CARD",
"GAME WORD",
"GAME CASUAL",
"GAME RACING",
"GAME STRATEGY",
"GAME CASINO",
"GAME EDUCATIONAL",
"GAME PUZZLE",
"GAME BOARD",
"GAME ARCADE",
"GAME MUSIC",
"GAME TRIVIA",
"GAME ACTION",
"GAME ROLE PLAYING",
"GAME ADVENTURE",
"GAME SIMULATION",
"GAME SPORTS"],'5starsum':[game_action_5star,
game_word_5star,
game_card_5star,
game_causual_5star,
game_strategy_5star,
game_adventure_5star,
game_edu_5star,
game_sports_5star,
game_board_5star,
game_sim_5star,
game_trivia_5star,
game_puzzle_5star,
game_music_5star,
game_arcade_5star,
game_casino_5star,
game_role_5star,
game_racing_5star]}

df=pd.DataFrame(data)
df["5starsum"].max()
# Out:
# 297452920

# %% [markdown]
# Game action

# %% [markdown]
# # most game growth (30 days)

# %%
game_action_30 = game_action["growth (30 days)"].max()
game_word_30 = game_word["growth (30 days)"].max()
game_card_30 = game_card["growth (30 days)"].max()
game_causual_30 = game_causual["growth (30 days)"].max()
game_strategy_30 = game_strategy["growth (30 days)"].max()
game_adventure_30 = game_adventure["growth (30 days)"].max()
game_edu_30 = game_edu["growth (30 days)"].max()
game_sports_30 = game_sports["growth (30 days)"].max()
game_board_30 = game_board["growth (30 days)"].max()
game_sim_30 = game_sim["growth (30 days)"].max()
game_trivia_30 = game_trivia["growth (30 days)"].max()
game_puzzle_30 = game_puzzle["growth (30 days)"].max()
game_music_30 = game_music["growth (30 days)"].max()
game_arcade_30 = game_arcade["growth (30 days)"].max()
game_casino_30 = game_casino["growth (30 days)"].max()
game_role_30 = game_role["growth (30 days)"].max()
game_racing_30 = game_racing["growth (30 days)"].max()

# %%
data={'Name':["GAME CARD",
"GAME WORD",
"GAME CASUAL",
"GAME RACING",
"GAME STRATEGY",
"GAME CASINO",
"GAME EDUCATIONAL",
"GAME PUZZLE",
"GAME BOARD",
"GAME ARCADE",
"GAME MUSIC",
"GAME TRIVIA",
"GAME ACTION",
"GAME ROLE PLAYING",
"GAME ADVENTURE",
"GAME SIMULATION",
"GAME SPORTS"],'growth30':[game_action_30,
game_word_30,
game_card_30,
game_causual_30,
game_strategy_30,
game_adventure_30,
game_edu_30,
game_sports_30,
game_board_30,
game_sim_30,
game_trivia_30,
game_puzzle_30,
game_music_30,
game_arcade_30,
game_casino_30,
game_role_30,
game_racing_30]}

game_30_60_max=pd.DataFrame(data)
game_30_60_max
#game word,game card,game board,game music,game edu, game sports, game casino, game stradegy, game role, game arcade
# Out:
#                  Name  growth30
# 0           GAME CARD  139410.4
# 1           GAME WORD  140394.4
# 2         GAME CASUAL      90.9
# 3         GAME RACING       NaN
# 4       GAME STRATEGY    1568.1
# 5         GAME CASINO    2558.2
# 6    GAME EDUCATIONAL    4130.4
# 7         GAME PUZZLE      19.4
# 8          GAME BOARD   15539.3
# 9         GAME ARCADE     547.4
# 10         GAME MUSIC    4661.3
# 11        GAME TRIVIA     131.6
# 12        GAME ACTION      63.4
# 13  GAME ROLE PLAYING    1334.9
# 14     GAME ADVENTURE      99.1
# 15    GAME SIMULATION      11.8
# 16        GAME SPORTS    3988.1

# %%
#game word,game card,game board,game music,game edu, game sports, game casino, game stradegy, game role, game arcade
game_action
game_word
game_card
game_causual
game_strategy
game_adventure
game_edu
game_sports
game_board
game_sim
game_trivia
game_puzzle
game_music
game_arcade
game_casino
game_role
game_racing
# Out:
#       rank                                              title  total ratings  \
# 1024     1                                  Hill Climb Racing       10109437
# 1025     2  Asphalt 8 Racing Game - Drive, Drift at Real S...        9501337
# 1026     3                                      Traffic Rider        7501902
# 1027     4                                      Real Racing 3        6618421
# 1028     5                                      Traffic Racer        6028847
# ...    ...                                                ...            ...
# 1119    96                  🚓🚦Car Driving School Simulator 🚕🚸         288523
# 1120    97                  Redline Rush: Police Chase Racing         288296
# 1121    98                         Monster Truck Destruction™         283643
# 1122    99                        Stickman Downhill Motocross         283083
# 1123   100                                      MMX Hill Dash         282767
#
# ...

# %%
game_30_60_max["growth30"].sort_values(ascending=False).head(10)
# Out:
# 1     140394.4
# 0     139410.4
# 8      15539.3
# 10      4661.3
# 6       4130.4
# 16      3988.1
# 5       2558.2
# 4       1568.1
# 13      1334.9
# 9        547.4
# Name: growth30, dtype: float64

# %%
game_word_30name = game_word[game_word["growth (30 days)"] == 140394.4]
game_word_30name
# Out:
#       rank                                title  total ratings installs  \
# 1680    51  Fill-The-Words - word search puzzle         275831   10.0 M
#
#       average rating  growth (30 days)  growth (60 days)  price   category  \
# 1680            4.62          140394.4               0.5    0.0  GAME WORD
#
#       5 star ratings  4 star ratings  3 star ratings  2 star ratings  \
# 1680          222986           27985            9062            3976
#
#       1 star ratings   paid
# 1680           11819  False

# %%
game_card[game_card["growth (30 days)"] == 139410.4]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_board[game_board["growth (30 days)"] == 15539.3]
# Out:
#      rank                                          title  total ratings  \
# 398    99  Ludo Neo-Classic : King of the Dice Game 2020          92272
#
#     installs  average rating  growth (30 days)  growth (60 days)  price  \
# 398   10.0 M             4.1           15539.3               0.3    0.0
#
#        category  5 star ratings  4 star ratings  3 star ratings  \
# 398  GAME BOARD           60808            9219            5783
#
#      2 star ratings  1 star ratings   paid
# 398            3805           12655  False

# %%
game_music[game_music["growth (30 days)"] == 4661.3]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_edu[game_edu["growth (30 days)"] == 4130.4]
# Out:
#      rank                                        title  total ratings  \
# 815    92  Little Panda’s Space Kitchen - Kids Cooking          50320
#
#     installs  average rating  growth (30 days)  growth (60 days)  price  \
# 815   10.0 M             4.2            4130.4               8.1    0.0
#
#              category  5 star ratings  4 star ratings  3 star ratings  \
# 815  GAME EDUCATIONAL           36062            3285            2489
#
#      2 star ratings  1 star ratings   paid
# 815            1961            6521  False

# %%
game_sports[game_sports["growth (30 days)"]== 3988.1]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_casino[game_casino["growth (30 days)"]==2558.2]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_strategy[game_strategy["growth (30 days)"]==1568.1]
# Out:
#       rank         title  total ratings installs  average rating  \
# 1425     2  Clash Royale       30599283  100.0 M            4.22
#
#       growth (30 days)  growth (60 days)  price       category  \
# 1425            1568.1               1.1    0.0  GAME STRATEGY
#
#       5 star ratings  4 star ratings  3 star ratings  2 star ratings  \
# 1425        20850163         3634022         1653329          771855
#
#       1 star ratings   paid
# 1425         3689911  False

# %%
game_role[game_role["growth (30 days)"]==1334.9]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_arcade[game_arcade["growth (30 days)"]==547.9]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %% [markdown]
# # most game growth 60 days

# %%
android.groupby("category").max().reset_index()
# Out:
#              category  rank                                      title  \
# 0         GAME ACTION   100                                 slither.io
# 1      GAME ADVENTURE   100                               ﻿Dragon Land
# 2         GAME ARCADE   100                                       윈드러너
# 3          GAME BOARD   100                                    인생역전윷놀이
# 4           GAME CARD   100                      한게임 신맞고 : 대한민국 원조 고스톱
# 5         GAME CASINO   100      麻將 明星3缺1麻將–台灣16張麻將Mahjong 、SLOT、Poker
# 6         GAME CASUAL   100                            World Chef 🍰🍔🍝🍓
# 7    GAME EDUCATIONAL   100                       超級單字王 - 英檢、多益、托福 輕鬆學
# 8          GAME MUSIC   100                                       더뮤지션
# 9         GAME PUZZLE   100                                       애니팡2
# 10        GAME RACING   100          🚓🚦Car Driving School Simulator 🚕🚸
# 11  GAME ROLE PLAYING   100                                      세븐나이츠
# ...

# %%
sorted_growthratings = android.sort_values(["growth (60 days)","average rating","total ratings"], ascending=False)

# %%
game_word_bool = sorted_growthratings["category"]=="GAME WORD"

# %%
sorted_growthratings[game_word_bool].head(1)
# Out:
#       rank                                              title  total ratings  \
# 1643    20  Braindom 2: Who is Lying? Fun Brain Teaser Rid...         600422
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# 1643   10.0 M            4.57              10.8              26.6    0.0
#
#        category  5 star ratings  4 star ratings  3 star ratings  \
# 1643  GAME WORD          495650           38015           18553
#
#       2 star ratings  1 star ratings   paid
# 1643            9434           38767  False

# %%
top_growth_games = []
for category in android["category"].unique():
    cat_bool = sorted_growthratings["category"]==category
    top_growth_games.append(sorted_growthratings[cat_bool].head(1))
top_growth_games
pd.concat(top_growth_games)
# Out:
#       rank                                              title  total ratings  \
# 14      15                                         Standoff 2        4457338
# 160     61                                      Manor Matters         302428
# 232     33                                      Join Clash 3D        1307348
# 395     96  Tile Connect - Free Tile Puzzle & Match Brain ...          94983
# 519    100                                          Solitaire          90029
# 583     62                       Slots Free - Big Win Casino™         173372
# 678     57                            Idle Arks: Build at Sea         758992
# 799     76       My Town : Best Friends' House games for kids          57996
# 900     77                Piano Fire - EDM Music & New Rhythm          53605
# 1001    78     Harry Potter: Puzzles & Spells - Match-3 Magic         486566
# 1116    93                                CarX Drift Racing 2         290482
# ...

# %%
game_action_60 = game_action["growth (60 days)"].max()
game_word_60 = game_word["growth (60 days)"].max()
game_card_60 = game_card["growth (60 days)"].max()
game_causual_60 = game_causual["growth (60 days)"].max()
game_strategy_60 = game_strategy["growth (60 days)"].max()
game_adventure_60 = game_adventure["growth (60 days)"].max()
game_edu_60 = game_edu["growth (60 days)"].max()
game_sports_60 = game_sports["growth (60 days)"].max()
game_board_60 = game_board["growth (60 days)"].max()
game_sim_60 = game_sim["growth (60 days)"].max()
game_trivia_60 = game_trivia["growth (60 days)"].max()
game_puzzle_60 = game_puzzle["growth (60 days)"].max()
game_music_60 = game_music["growth (60 days)"].max()
game_arcade_60 = game_arcade["growth (60 days)"].max()
game_casino_60 = game_casino["growth (60 days)"].max()
game_role_60 = game_role["growth (60 days)"].max()
game_racing_60 = game_racing["growth (60 days)"].max()

# %%
data={'Name':["GAME CARD",
"GAME WORD",
"GAME CASUAL",
"GAME RACING",
"GAME STRATEGY",
"GAME CASINO",
"GAME EDUCATIONAL",
"GAME PUZZLE",
"GAME BOARD",
"GAME ARCADE",
"GAME MUSIC",
"GAME TRIVIA",
"GAME ACTION",
"GAME ROLE PLAYING",
"GAME ADVENTURE",
"GAME SIMULATION",
"GAME SPORTS"],'growth30':[game_action_30,
game_word_30,
game_card_30,
game_causual_30,
game_strategy_30,
game_adventure_30,
game_edu_30,
game_sports_30,
game_board_30,
game_sim_30,
game_trivia_30,
game_puzzle_30,
game_music_30,
game_arcade_30,
game_casino_30,
game_role_30,
game_racing_30],'growth60':[game_action_60,
game_word_60,
game_card_60,
game_causual_60,
game_strategy_60,
game_adventure_60,
game_edu_60,
game_sports_60,
game_board_60,
game_sim_60,
game_trivia_60,
game_puzzle_60,
game_music_60,
game_arcade_60,
game_casino_60,
game_role_60,
game_racing_60]}

game_30_60_max=pd.DataFrame(data)
game_30_60_max
#game word,game card,game board,game music,game edu, game sports, game casino, game stradegy, game role, game arcade
# Out:
#                  Name  growth30  growth60
# 0           GAME CARD  139410.4      13.7
# 1           GAME WORD  140394.4      26.6
# 2         GAME CASUAL      90.9      27.5
# 3         GAME RACING       NaN       NaN
# 4       GAME STRATEGY    1568.1      47.4
# 5         GAME CASINO    2558.2      69.0
# 6    GAME EDUCATIONAL    4130.4     605.1
# 7         GAME PUZZLE      19.4      63.7
# 8          GAME BOARD   15539.3      88.3
# 9         GAME ARCADE     547.4      44.7
# 10         GAME MUSIC    4661.3     250.6
# 11        GAME TRIVIA     131.6      21.3
# 12        GAME ACTION      63.4     325.8
# 13  GAME ROLE PLAYING    1334.9      67.5
# 14     GAME ADVENTURE      99.1      48.1
# 15    GAME SIMULATION      11.8      29.6
# 16        GAME SPORTS    3988.1      13.9

# %%
game_30_60_max["growth60"].sort_values(ascending=False).head(10)
#edu,action.music,board,casino,role,puzzle,adventure,stradegy,arcade
# Out:
# 6     605.1
# 12    325.8
# 10    250.6
# 8      88.3
# 5      69.0
# 13     67.5
# 7      63.7
# 14     48.1
# 4      47.4
# 9      44.7
# Name: growth60, dtype: float64

# %%
game_action[game_action["growth (60 days)"]==325.8]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_strategy[game_strategy["growth (60 days)"]==47.4]
# Out:
#       rank                          title  total ratings installs  \
# 1458    35  Rise of Empires: Ice and Fire         857214   10.0 M
#
#       average rating  growth (30 days)  growth (60 days)  price  \
# 1458             4.7              17.8              47.4    0.0
#
#            category  5 star ratings  4 star ratings  3 star ratings  \
# 1458  GAME STRATEGY          726232           68289           25678
#
#       2 star ratings  1 star ratings   paid
# 1458            8089           28923  False

# %%
game_adventure[game_adventure["growth (60 days)"]==48.1]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_edu[game_edu["growth (60 days)"]==605.1]
# Out:
#      rank                                         title  total ratings  \
# 799    76  My Town : Best Friends' House games for kids          57996
#
#     installs  average rating  growth (30 days)  growth (60 days)  price  \
# 799    5.0 M            4.18              26.8             605.1    0.0
#
#              category  5 star ratings  4 star ratings  3 star ratings  \
# 799  GAME EDUCATIONAL           40743            4476            2753
#
#      2 star ratings  1 star ratings   paid
# 799            2578            7444  False

# %%
game_board[game_board["growth (60 days)"]==88.3]
# Out:
#      rank                                              title  total ratings  \
# 395    96  Tile Connect - Free Tile Puzzle & Match Brain ...          94983
#
#     installs  average rating  growth (30 days)  growth (60 days)  price  \
# 395   10.0 M            4.56              30.0              88.3    0.0
#
#        category  5 star ratings  4 star ratings  3 star ratings  \
# 395  GAME BOARD           72273           13796            3129
#
#      2 star ratings  1 star ratings   paid
# 395            1346            4437  False

# %%
game_puzzle[game_puzzle["growth (60 days)"]==63.7]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_music[game_music["growth (60 days)"]==250.6]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_arcade[game_arcade["growth (60 days)"]==44.7]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_role[game_role["growth (60 days)"]==67.5]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %%
game_casino[game_casino["growth (60 days)"]==69.0]
# Out:
# Empty DataFrame
# Columns: [rank, title, total ratings, installs, average rating, growth (30 days), growth (60 days), price, category, 5 star ratings, 4 star ratings, 3 star ratings, 2 star ratings, 1 star ratings, paid]
# Index: []

# %% [markdown]
# # installs

# %%
android
# Out:
#       rank                                         title  total ratings  \
# 0        1                  Garena Free Fire - The Cobra       80678661
# 1        2                   PUBG MOBILE: Graffiti Prank       35971961
# 2        3                     Mobile Legends: Bang Bang       25836869
# 3        4                                   Brawl Stars       17181659
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14237554
# ...    ...                                           ...            ...
# 1725    96                     Piknik Słowo - Word Snack         122845
# 1726    97           Wordox – Free multiplayer word game         120476
# 1727    98                             4 Fotos 1 Palavra         114852
# 1728    99                 زوايا - لعبة ستحرك زوايا عقلك         110293
# 1729   100         Word Life - Connect crosswords puzzle         109809
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
android["installs"].value_counts()
# Out:
# 10.0 M      795
# 50.0 M      266
# 5.0 M       248
# 100.0 M     203
# 1.0 M       191
# 500.0 k      13
# 500.0 M      10
# 1000.0 M      2
# 100.0 k       2
# Name: installs, dtype: int64

# %%
androidstripM = android["installs"].str.replace("500.0 k","0.5 M").str.replace("100.0 k","0.1 M").str.replace("M", "").str.strip().astype(float)
androidstripM
# Out:
# /var/folders/kk/3z8pfysj6hz072vqxmn2b5740000gp/T/ipykernel_41034/1417283703.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   androidstripM = android["installs"].str.replace("500.0 k","0.5 M").str.replace("100.0 k","0.1 M").str.replace("M", "").str.strip().astype(float)
# 0       500.0
# 1       100.0
# 2       100.0
# 3       100.0
# 4       100.0
#         ...
# 1725      1.0
# 1726      1.0
# 1727      5.0
# 1728      1.0
# 1729      5.0
# Name: installs, Length: 1730, dtype: float64

# %%
android["androidstripM"] = androidstripM

# %%
android["category"].value_counts()
# Out:
# GAME CARD            122
# GAME WORD            106
# GAME CASUAL          102
# GAME RACING          100
# GAME TRIVIA          100
# GAME STRATEGY        100
# GAME SPORTS          100
# GAME SIMULATION      100
# GAME ROLE PLAYING    100
# GAME ACTION          100
# GAME PUZZLE          100
# GAME ADVENTURE       100
# GAME EDUCATIONAL     100
# GAME CASINO          100
# GAME BOARD           100
# GAME ARCADE          100
# GAME MUSIC           100
# Name: category, dtype: int64

# %%
android
# Out:
#       rank                                         title  total ratings  \
# 0        1                  Garena Free Fire - The Cobra       80678661
# 1        2                   PUBG MOBILE: Graffiti Prank       35971961
# 2        3                     Mobile Legends: Bang Bang       25836869
# 3        4                                   Brawl Stars       17181659
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14237554
# ...    ...                                           ...            ...
# 1725    96                     Piknik Słowo - Word Snack         122845
# 1726    97           Wordox – Free multiplayer word game         120476
# 1727    98                             4 Fotos 1 Palavra         114852
# 1728    99                 زوايا - لعبة ستحرك زوايا عقلك         110293
# 1729   100         Word Life - Connect crosswords puzzle         109809
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
android.sort_values(["androidstripM","1 star ratings","5 star ratings"],ascending=[False,True,False])
# Out:
#       rank                       title  total ratings  installs  \
# 622      1            Candy Crush Saga       30859251  1000.0 M
# 200      1              Subway Surfers       35305263  1000.0 M
# 1332     9                 8 Ball Pool        2877308   500.0 M
# 208      9                  Temple Run        4744985   500.0 M
# 300      1                  Ludo King™        7048207   500.0 M
# ...    ...                         ...            ...       ...
# 477     64                      Reigns         146504   500.0 k
# 483     69                      三國殺名將傳         136809   500.0 k
# 1574    51             Free RBX Master         107289   500.0 k
# 1604    81                 فكر ـ Think          56783   100.0 k
# 888     65  Beat Bop: Pop Star Clicker          69141   100.0 k
#
#       average rating  growth (30 days)  growth (60 days)  price     category  \
# 622             4.56               0.7               1.6   0.00  GAME CASUAL
# ...

# %% [markdown]
# # Relationship between ratings and installs

# %%
relationship_between_rating = android[["total ratings", "androidstripM"]]

# %%
relationship_rating_plot = relationship_between_rating.plot.scatter(x="total ratings", y="androidstripM")

# %%
plotly_re = px.scatter(x=android["total ratings"], y=android["androidstripM"])
plotly_re.show()
# Out:
# <div>                            <div id="f628862e-af84-49ee-9c02-d882c705ae36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f628862e-af84-49ee-9c02-d882c705ae36")) {                    Plotly.newPlot(                        "f628862e-af84-49ee-9c02-d882c705ae36",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[80678661,35971961,25836869,17181659,14237554,14048931,13020115,11298789,9554877,7392911,6475640,6203689,5651287,5245027,4457338,4456347,4448938,4443546,4260419,4193941,4162892,4097530,4092418,3986647,3480214,3138199,3122764,3095661,3065898,3009445,2644544,2548363,2535575,2454177,2373080,2360988,23465
# ...

# %% [markdown]
# # Plot of 5 star and 1 star ratings

# %%
relationship_between_5star = android[["5 star ratings", "1 star ratings","title"]]

# %%
relationship_between_5star.plot.scatter(x="5 star ratings", y="1 star ratings")
# Out:
# <AxesSubplot:xlabel='5 star ratings', ylabel='1 star ratings'>

# %%
plotly_5star = px.scatter(android,x="5 star ratings", y="1 star ratings", hover_name="title", color="category", 
                          color_discrete_sequence=px.colors.qualitative.Light24)
plotly_5star.show()
# Out:
# <div>                            <div id="5e690239-3499-4508-abf2-589ef4953769" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e690239-3499-4508-abf2-589ef4953769")) {                    Plotly.newPlot(                        "5e690239-3499-4508-abf2-589ef4953769",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>category=GAME ACTION<br>5 star ratings=%{x}<br>1 star ratings=%{y}<extra></extra>","hovertext":["Garena Free Fire - The Cobra","PUBG MOBILE: Graffiti Prank","Mobile Legends: Bang Bang","Brawl Stars","Sniper 3D: Fun Free Online FPS Shooting Game","Shadow Fight 2","Call of Duty\u00ae: Mobile - Day of Reckoning","Among Us","Temple Run 2","PUBG MOBILE LITE","slither.io","Gangstar Vegas: World of Crime","Pixel Gun 3D: FPS S
# ...

# %%
android[android["category"].isin(["GAME STRADEGY", "GAME ARCADE", "GAME CASUAL"])]
# Out:
#      rank                                           title  total ratings  \
# 200     1                                  Subway Surfers       35305263
# 201     2  Hungry Shark Evolution - Offline survival game        7141044
# 202     3                              Geometry Dash Lite        6894310
# 203     4                                  Zombie Tsunami        5855907
# 204     5                             Angry Birds Classic        5683301
# ..    ...                                             ...            ...
# 719    96                        Moy 5 - Virtual Pet Game         455667
# 720    97                                       LINE 旅遊大亨         444030
# 721    98                               Little Big City 2         439524
# 722    99                                Mini Block Craft         437733
# 723   100            Kids Doodle - Color & Draw Free Game         429996
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %% [markdown]
# # Ratio of 5 star to one star

# %%
fives = android["5 star ratings"]

# %%
ones = android["1 star ratings"]

# %%
ratio = fives/ones

# %%
bar = px.bar(x=ratio)
bar.show()
# Out:
# <div>                            <div id="1e35fdc4-28c8-488a-9e1f-13b7d0dc59a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e35fdc4-28c8-488a-9e1f-13b7d0dc59a4")) {                    Plotly.newPlot(                        "1e35fdc4-28c8-488a-9e1f-13b7d0dc59a4",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[6.415524614210614,5.392919754167342,4.059209485087456,5.981320205421248,9.2336384800348,12.962838525186285,10.286078587041485,2.275073744953929,6.0502736904607275,4.795312637491567,4.630042286768827,6.766892424242425,5.0277879198831
# ...
